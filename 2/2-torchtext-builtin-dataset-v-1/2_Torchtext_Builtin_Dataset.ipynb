# %%
import spacy
from torchtext.legacy.datasets import Multi30k
from torchtext.legacy.data import Field, BucketIterator

# %%
# !python -m spacy download de
# Out:
# Collecting de_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.2.5/de_core_news_sm-2.2.5.tar.gz (14.9 MB)
#      |████████████████████████████████| 14.9 MB 5.0 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from de_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.19.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->de_core_news_sm==2.2.5) (2.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.6.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->de_core_news_sm==2.2.5) (1.24.3)
# Building wheels for collected packages: de-core-news-sm
#   Building wheel for de-core-news-sm (setup.py) ... done
#   Created wheel for de-core-news-sm: filename=de_core_news_sm-2.2.5-py3-none-any.whl size=14907055 sha256=bf4a3051a693a330f48b2396a0bd770fb1ab3f25167210b3414e1bf79e762c73
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tj7n3alt/wheels/00/66/69/cb6c921610087d2cab339062345098e30a5ceb665360e7b32a
# Successfully built de-core-news-sm
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('de_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/de_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/de
# You can now load the model via spacy.load('de')

# %%
spacy_en = spacy.load("en")
spacy_ger = spacy.load("de")

# %%
def tokenize_en(text):
  return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
def tokenize_ger(text):
  return [tok.text for tok in spacy_ger.tokenizer(text)]

# %%
english = Field(sequential=True, use_vocab=True, tokenize=tokenize_en, lower=True)
german = Field(sequential=True, use_vocab=True, tokenize=tokenize_ger, lower=True)

# %%
train_data, validation_data, test_data = Multi30k.splits(
    exts=(".de", ".en"),
    fields=(german, english),
)
# Out:
# downloading training.tar.gz
# 100%|██████████| 1.21M/1.21M [00:01<00:00, 748kB/s]
# downloading validation.tar.gz
# 100%|██████████| 46.3k/46.3k [00:00<00:00, 154kB/s]
# downloading mmt_task1_test2016.tar.gz
# 100%|██████████| 66.2k/66.2k [00:00<00:00, 218kB/s]

# %%
english.build_vocab(train_data, max_size=10000, min_freq=2)
german.build_vocab(train_data, max_size=10000, min_freq=2)

# %%
train_iterator, validation_iterator, test_iterator = BucketIterator.splits(
    (train_data, validation_data, test_data),
    batch_size=64,
    device="cuda"
)

# %%
for batch in train_iterator:
  print(batch)
# Out:
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 18x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 44x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 43x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 40x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# ...
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 38x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 36x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 39x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 29x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 41x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 33x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 20x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 32x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 28x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 31x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 25x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 34x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 35x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 26x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 27x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 24x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 19x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 30x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 23x64 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 8 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 16x8 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 15x8 (GPU 0)]
#
# [torchtext.legacy.data.batch.Batch of size 64 from MULTI30K]
# 	[.src]:[torch.cuda.LongTensor of size 22x64 (GPU 0)]
# 	[.trg]:[torch.cuda.LongTensor of size 21x64 (GPU 0)]

# %%
print(english.vocab.stoi["the"])
print(english.vocab.itos[5])
# Out:
# 5
# the
